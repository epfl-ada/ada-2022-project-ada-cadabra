# %%
import pandas as pd
import numpy as np
import gzip #to read gzip files
import matplotlib.pyplot as plt
import datetime
import pickle
from scipy.stats import linregress

# %% [markdown]
# ## Data Extraction

# %%
PATH = '../'

# %%
BA_beers = pd.read_csv(PATH+'df_BA_reviews.csv', index_col='beer_id')
BA_beers.head(2)
# Out:
#              beer_name                               brewery_name  brewery_id  \
# beer_id
# 142544           Régab  Societe des Brasseries du Gabon (SOBRAGA)       37262
# 19590    Barelegs Brew       Strangford Lough Brewing Company Ltd       10093
#
#                     style  abv                 date    user_name  \
# beer_id
# 142544    Euro Pale Lager  4.5  2015-08-20 10:00:00      nmann08
# 19590    English Pale Ale  4.5  2009-02-20 11:00:00  StJamesGate
#
#                     user_id  appearance  aroma  palate  taste  overall  \
# beer_id
# 142544       nmann08.184925        3.25   2.75    3.25   2.75      3.0
# 19590    stjamesgate.163714        3.00   3.50    3.50   4.00      3.5
#
#          rating                                               text
# beer_id
# 142544     2.88  From a bottle, pours a piss yellow color with ...
# 19590      3.67  Pours pale copper with a thin head that quickl...

# %%
RB_beers = pd.read_csv(PATH+'df_RB_reviews_final.csv', index_col='beer_id')
RB_beers.head(2)
# Out:
#                    beer_name brewery_name  brewery_id       style  abv  \
# beer_id
# 410549     33 Export (Gabon)      Sobraga        3198  Pale Lager  5.0
# 105273   Castel Beer (Gabon)      Sobraga        3198  Pale Lager  5.2
#
#                         date     user_name  user_id  appearance  aroma  \
# beer_id
# 410549   2016-04-26 10:00:00       Manslow   175852           2      4
# 105273   2017-02-17 11:00:00  MAGICuenca91   442761           2      3
#
#          palate  taste  overall  rating  \
# beer_id
# 410549        2      4        8     2.0
# 105273        2      4        8     1.9
#
#                                                       text
# beer_id
# 410549   Puszka 0,33l dzięki Christoph . Kolor jasnozło...
# 105273   Cerveza pale lager gabonesa. MÃ¡s floja que la...

# %%
matched_beers = pd.read_csv(PATH+'matched_beer_data/beers.csv')
matched_beers.head(2)
# Out:
# /var/folders/0y/rc7z1xc16bzcgrzdjw056njw0000gn/T/ipykernel_24014/1075737016.py:1: DtypeWarning: Columns (0,1,2,3,4,5,8,10,11,12,13,15,16,17,18,19,20,23,25,26,27,29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   matched_beers = pd.read_csv(PATH+'matched_beer_data/beers.csv')
#     ba  ba.1               ba.2                       ba.3      ba.4     ba.5  \
# 0  abv   avg       avg_computed  avg_matched_valid_ratings  ba_score  beer_id
# 1  4.8  3.45  3.439866666666666          3.504067796610169      80.0    19827
#
#         ba.6                    ba.7        ba.8  \
# 0  beer_name  beer_wout_brewery_name  brewery_id
# 1   Legbiter                Legbiter       10093
#
#                                    ba.9  ...        rb.7              rb.8  \
# 0                          brewery_name  ...  brewery_id      brewery_name
# 1  Strangford Lough Brewing Company Ltd  ...        4959  Strangford Lough
#
#                         rb.9        rb.10          rb.11  \
# 0  nbr_matched_valid_ratings  nbr_ratings  overall_score
# 1                         89           89           23.0
#
#                   rb.12        rb.13              rb.14 scores scores.1
# 0                 style  style_score             zscore   diff      sim
# 1  Golden Ale/Blond Ale         27.0  -0.69830388113311    1.0      1.0
#
# [2 rows x 33 columns]

# %%
matched_breweries = pd.read_csv(PATH+'matched_beer_data/breweries.csv')
matched_breweries.head(2)
# Out:
#       ba              ba.1                                  ba.2       ba.3  \
# 0     id          location                                  name  nbr_beers
# 1  10093  Northern Ireland  Strangford Lough Brewing Company Ltd          5
#
#      rb              rb.1              rb.2       rb.3               scores  \
# 0    id          location              name  nbr_beers                 diff
# 1  4959  Northern Ireland  Strangford Lough          5  0.43127548708778424
#
#              scores.1
# 0                 sim
# 1  0.8890620997705575

# %%
matched_ratings = pd.read_csv(PATH+'matched_beer_data/ratings.csv', encoding = "ISO-8859-1")
matched_ratings.head(2)
# Out:
# /var/folders/0y/rc7z1xc16bzcgrzdjw056njw0000gn/T/ipykernel_24014/2201272280.py:1: DtypeWarning: Columns (0,1,2,3,5,7,8,9,10,11,13,17,18,19,20,22,24,25,26,27,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   matched_ratings = pd.read_csv(PATH+'matched_beer_data/ratings.csv', encoding = "ISO-8859-1")
#      ba        ba.1   ba.2     ba.3                     ba.4        ba.5  \
# 0   abv  appearance  aroma  beer_id                beer_name  brewery_id
# 1  11.3         4.5    4.5      645  Trappistes Rochefort 10         207
#
#                      ba.6        ba.7     ba.8    ba.9  ...  \
# 0            brewery_name        date  overall  palate  ...
# 1  Brasserie de Rochefort  1324810800      5.0     4.5  ...
#
#                   rb.6        rb.7     rb.8    rb.9   rb.10          rb.11  \
# 0         brewery_name        date  overall  palate  rating          style
# 1  Brasserie Rochefort  1387710000     19.0     4.0     4.6  Abt/Quadrupel
#
#    rb.12                                              rb.13    rb.14  \
# 0  taste                                               text  user_id
# 1    9.0   a)  Geruch malzig-schwer-sÃÂ¼ÃÂ. Riecht sc...    83106
#
#        rb.15
# 0  user_name
# 1   Erzengel
#
# [2 rows x 33 columns]

# %% [markdown]
# # Effect of sensory values on beer ratings

# %% [markdown]
# Extracting BeerAdvocate data:

# %%
df_ratings_BA = matched_ratings.iloc[:,:17]
df_ratings_BA.set_axis(df_ratings_BA.loc[0], axis='columns', inplace=True)
df_ratings_BA = df_ratings_BA.drop(0)
df_ratings_BA.head(2)
# Out:
# /var/folders/0y/rc7z1xc16bzcgrzdjw056njw0000gn/T/ipykernel_24014/1223964025.py:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df_ratings_BA.set_axis(df_ratings_BA.loc[0], axis='columns', inplace=True)
# 0   abv appearance aroma beer_id                beer_name brewery_id  \
# 1  11.3        4.5   4.5     645  Trappistes Rochefort 10        207
# 2   5.0        NaN   NaN   28191       Myanmar Lager Beer       9369
#
# 0                    brewery_name        date overall palate rating review  \
# 1          Brasserie de Rochefort  1324810800     5.0    4.5    4.8   True
# 2  Myanmar Brewery and Distillery  1322650800     NaN    NaN    3.0   True
#
# 0                   style taste  \
# 1        Quadrupel (Quad)   5.0
# 2  American Adjunct Lager   NaN
#
# 0                                               text             user_id  \
# 1  Best before 27.07.2016Directly reviewed in com...     erzengel.248045
# 2                                                NaN  visionthing.639993
#
# 0    user_name
# 1     Erzengel
# 2  visionthing

# %% [markdown]
# Extracting RateBeer data:

# %%
df_ratings_RB = matched_ratings.iloc[:,17:]
df_ratings_RB.set_axis(df_ratings_RB.loc[0], axis='columns', inplace=True)
df_ratings_RB = df_ratings_RB.drop(0)

df_ratings_RB.head(2)
# Out:
# /var/folders/0y/rc7z1xc16bzcgrzdjw056njw0000gn/T/ipykernel_24014/699616818.py:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df_ratings_RB.set_axis(df_ratings_RB.loc[0], axis='columns', inplace=True)
# 0   abv appearance aroma beer_id                beer_name brewery_id  \
# 1  11.3        4.0  10.0    2360  Rochefort Trappistes 10        406
# 2   5.0        2.0   3.0   17109       Myanmar Lager Beer       2921
#
# 0                    brewery_name        date overall palate rating  \
# 1             Brasserie Rochefort  1387710000    19.0    4.0    4.6
# 2  Myanmar Brewery and Distillery  1322564400     6.0    2.0    1.7
#
# 0          style taste                                               text  \
# 1  Abt/Quadrupel   9.0   a)  Geruch malzig-schwer-sÃÂ¼ÃÂ. Riecht sc...
# 2     Pale Lager   4.0  Can. Weak and watery, not the best beer of the...
#
# 0 user_id    user_name
# 1   83106     Erzengel
# 2   91324  visionthing

# %%
def getLinearRegression(df, attr): 
    df['rating']=np.float64(df['rating'])
    df[attr]=np.float64(df[attr])
    reviews = pd.DataFrame(df[[attr,'rating']]).dropna()
    x = reviews[attr]
    xmin = x.min()
    xmax = x.max()
    y = reviews['rating']
    x = x.tolist()
    y = y.tolist()
    regress = linregress(x,y)
    lr = regress
    a1 = lr[0]*xmin + lr[1]
    a2 = lr[0]*xmax + lr[1]
    return lr, a1, a2, xmin, xmax

# %% [markdown]
# This is a method to calculate the linear regression for a an attribute of the beer and its ratings. The function returns the linear regression object, and the minimum and maximum x (the attribute) and y (the regression result) values.

# %%
def showPlot(df):
    fig, axs = plt.subplots(2, 2)
    lr, a1, a2, xmin, xmax = getLinearRegression(df, 'palate')
    axs[0, 0].scatter(df['palate'], df['rating'], s=.5, alpha=.7, color='purple')
    axs[0, 0].plot([xmin,xmax],[a1,a2], 'k-')
    axs[0, 0].set(xlabel='Palate rating', ylabel='Overall rating')
    axs[0, 0].set_title(f'(R Value: {np.round(lr[2], 3)})')

    lr, a1, a2, xmin, xmax = getLinearRegression(df, 'aroma')
    axs[0, 1].scatter(df['aroma'], df['rating'], s=.5, alpha=.7, color='purple')
    axs[0, 1].plot([xmin,xmax],[a1,a2], 'k-')
    axs[0, 1].set(xlabel='Aroma rating', ylabel='Overall rating')
    axs[0, 1].set_title(f'(R Value: {np.round(lr[2], 3)})')

    lr, a1, a2, xmin, xmax = getLinearRegression(df, 'taste')
    axs[1, 0].scatter(df['taste'], df['rating'], s=.5, alpha=.7, color='purple')
    axs[1, 0].plot([xmin,xmax],[a1,a2], 'k-')
    axs[1, 0].set(xlabel='Taste rating', ylabel='Overall rating')
    axs[1, 0].set_title(f'(R Value: { np.round(lr[2], 3)})')

    lr, a1, a2, xmin, xmax = getLinearRegression(df, 'appearance')
    axs[1, 1].scatter(df['appearance'], df['rating'], s=.5, alpha=.7, color='purple')
    axs[1, 1].plot([xmin,xmax],[a1,a2], 'k-')
    axs[1, 1].set(xlabel='Appearance rating', ylabel='Overall rating')
    axs[1, 1].set_title(f'(R Value: { np.round(lr[2], 3)})')

    fig.tight_layout()
    plt.show()

# %%
showPlot(df_ratings_BA)

# %%
showPlot(df_ratings_RB)

# %% [markdown]
# Above we make a subplot containing the linear relationships of all the key sensory beer values with their ratings. We use the r_value from the linear regresion object which indicates the Pearson's correlation coefficient (the strength of the linear relationship) between the two values. We find that taste has the strongest linear relationship with the rating of the beer, followed by the aroma. This relationship is observed in both, BeerAdvocate and RateBeer, datasets.
